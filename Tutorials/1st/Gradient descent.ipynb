# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1° example:
#
# #### Function to find minimum
# $ f(x) = x^4 - 3 x^3 $
#
# #### First order derivative
# $ f'(x) = 4x^3 - 9 x^2 $

# %%
# Function
f = lambda x: x**4 - 3 * x**3
df = lambda x: 4 * x**3 - 9 * x**2

# %%
x = np.linspace(-1,3,1000) # 100 linearly spaced numbers
y = np.array([f(i) for i in x])

# compose plot
plt.plot(x,y) # sin(x)/x
plt.show() # show the plot

# %%
# Starting point (can be randomly chosen)
x = 4

# Learning rate
LR = 0.01

# Iterate
for i in range(5000):
    # Gradient descent
    x = x - LR * df(x)

print(x)
# Out:
# 2.2500000000000013

# %% [markdown]
# ### 2° example:
#
# #### Function to find minimum
# $ f(x) = 3x - log(x) $
#
# #### First order derivative
# $ f'(x) = 3 - (1 / x) $

# %%
f = lambda x: 3*x - math.log(x)
df = lambda x: 3 - (1./x)

# %%
x = np.linspace(0.01,2,1000) # 100 linearly spaced numbers
y = np.array([f(i) for i in x])

# compose plot
plt.plot(x,y) # sin(x)/x
plt.show() # show the plot

# %%
# Starting point (can be randomly chosen)
x = 4

# Learning rate
LR = 0.01

for i in range(1000):
    x = x - LR * df(x)

print(x)
# Out:
# 0.33333333333333365
