# %% [markdown]
# # Time Series Forecasting with LSTM
#
# The network architecture of Long Short-Term Memory Networks (LSTM) is optimized for learning sequences of events. For example, we can use LSTM to learn how texts are structured and use them to predict the most likely next word in a sentence.
#
# Another application is the forecast of time-series that are time-ordered
# sequences of events. For example, the stock price of a share can be interpreted as a time series, as well as  the sales of a product and many more.
#
# In this notebook, we illustrate the principle of time-series forecasting with LSTM networks using a small generated dataset that consists of two sine functions with an additional noise term. We will use these networks to forecast the next data point in a series. In other words, we perform a "one step ahead" forecast predicting one element at the time.

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers

# %pylab inline
# large figures
rcParams['figure.figsize'] = 8, 6
print(tf.__version__)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 2.11.0

# %% [markdown]
# ## Generate Data
#
# We now create a small artificial dataset from two sine functions with an additional  noise term. The signal is periodic and therefore relatively simple to learn, however, the high frequency component and noise allow for some complexity.

# %%
def generate_data(x_min, x_max, n_datapoints=300, f1 = 10, f2=20, offset1 = 0, offset2=0.2, noise=0.1):
    x = np.linspace(x_min, x_max, n_datapoints)
    y = 0.5*np.sin(f1*(x-offset1))+0.2*sin(f2*(x-offset2))+noise*np.random.rand(n_datapoints)-0.5
    return x,y

x,y = generate_data(x_min=0.0, x_max=10.0, n_datapoints=500,
                    f1=10, f2=17, offset1=0.1, offset2=0.3, noise=0.2)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Transform Data
#
# We now need to transform the data in to a sliding window of a fixed width.
# One key feature of sequences is that the data points are auto-correlated which means that the sequence of the data points matters.
# In "normal" supervised learning approaches we would shuffle the training data and reserve a fraction chosen at random as the test data.
# In the case of time-series data, we cannot do this as the sequence of the data points is a key aspect of the structure of a time series.
#
# LSTM networks are a supervised training network where we predict a label (y_train) from a number of training data (x_data). In our case, we take a part of the original training data by considering only a number n points at the time and then predict the element that would follow immediately after this sequence of n points.
# Then we shift the window by one time-step (or data point), consider the next window of n data-points and predict the one following the new sequence,
# and repeat the process until we have processed the complete time-series.
#
# Note that the first sequence of n points is used to create the first element of the sequence of the training targets y_train.
#
# We also need to determine the length of the sequence. In this example we will use 50 points to approximately capture one period of the signal.

# %%
#use 50 points for the window width
sequence_length = 50 
sequence = []
for index in range(len(y) - sequence_length):
    sequence.append(y[index: index + sequence_length +1])

sequence = np.array(sequence)

# %%
#
# Look at a few examples of the training sequences
#

plt.plot(sequence[0], label='seq 0')
plt.plot(sequence[1], label='seq 1')
plt.plot(sequence[2], label='seq 2')

#one towards the end
#seq_no = len(sequence)-int(len(sequence)/10.0)
#plt.plot(sequence[seq_no], label='seq '+ str(seq_no))

plt.legend()
plt.show()

# %% [markdown]
# We now split the sequences into a training and test dataset where
# we use 80% of the data for training and retain 20% as an independent
# test sample. Since the data points are auto-correlated, we cannot take a random sample, but need to take the last 20% of the data.
# First we calculate the appropriate index to split the sequences into a training and test sample.
#
# We then take the series of n data-points as the training data (x_train) and the next element in the series as the training target (y_train).
#
# Finally, we need to bring the training and test data (x_train and x_test) into the shape expected by the LSTM network. The LSTM layers expect a three-dimensional tensor as input, where the elements specify:
#    * the number of samples
#    * the length of the sequence
#    * the number of forecast steps. In our case we train the model to predict the element directly following the sequence and hence we set this to 1.

# %%
#use 80% for training, 20% for testing
train_index = round(0.8 * len(sequence))
print('The training data will run up to index {}'.format(train_index))

train = sequence[:int(train_index), :]
x_train = train[:, :-1]
y_train = train[:, -1]
x_test  = sequence[int(train_index):, :-1]
y_test  = sequence[int(train_index):, -1]

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) 

print(x_train.shape)
# Out:
# The training data will run up to index 360
# (360, 50, 1)

# %% [markdown]
# Let's plot the training and test data in sequence, using black for the training and red for the test data. In our case we generated the data such that we have values for the x-axes in a separate data field.

# %%
plt.plot(x[:train_index], y_train, label='Train', color='black',)
plt.plot(x[train_index:-sequence_length], y_test,  label='Test',  color='red', alpha=0.7)

plt.legend()
plt.show()

# %% [markdown]
# We now build a simple LSTM module with 50 nodes in the input layer and 100 nodes in the hidden layer. We also add a Dropout regularization after each LSTM layer.
#
# Note that we need to specify the parameter ```return_sequences=True``` for each LSTM layer that is followed by another LSTM layer. This ensures that the full sequence of data points is returned and can be processed by the next layer.
#
# We use the mean squared error (MSE) as loss function, a batch size of 64 samples and the Adam optimizer with default values to determine the best parameters of the network.

# %%
###
### build the model
###

model = tf.keras.Sequential()

model.add(layers.LSTM(units=50, input_shape=(sequence_length,1), return_sequences=True ))
model.add(layers.Dropout(0.2))
model.add(layers.LSTM(units=100, return_sequences=False))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(units=1))
model.add(layers.Activation('linear'))

model.compile(loss='mse', optimizer='adam')

###
### fit model
###
history = model.fit(x_train,y_train, batch_size=64, epochs=500, validation_split=0.05)
# Out:
# 2023-02-21 23:19:54.346906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:54.394444: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:54.395378: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:54.397490: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-21 23:19:54.399421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:54.400082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:54.400660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:55.360344: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:55.361227: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:55.361675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-21 23:19:55.362395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2229 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/500
# 2023-02-21 23:20:00.346661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-02-21 23:20:01.468308: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fa8b801c850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-02-21 23:20:01.468337: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti, Compute Capability 7.5
# 2023-02-21 23:20:01.493015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-02-21 23:20:01.776814: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 [==============================] - 7s 182ms/step - loss: 0.2495 - val_loss: 0.1450
# Epoch 2/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1645 - val_loss: 0.1164
# Epoch 3/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.1303 - val_loss: 0.0957
# Epoch 4/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0970 - val_loss: 0.0293
# Epoch 5/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0582 - val_loss: 0.0067
# Epoch 6/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0332 - val_loss: 0.0381
# Epoch 7/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0347 - val_loss: 0.0147
# Epoch 8/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0289 - val_loss: 0.0100
# Epoch 9/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0251 - val_loss: 0.0164
# Epoch 10/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0238 - val_loss: 0.0167
# Epoch 11/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0135
# Epoch 12/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0243 - val_loss: 0.0114
# Epoch 13/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0203 - val_loss: 0.0120
# Epoch 14/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0209 - val_loss: 0.0137
# Epoch 15/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0195 - val_loss: 0.0100
# Epoch 16/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0191 - val_loss: 0.0075
# Epoch 17/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0170 - val_loss: 0.0085
# Epoch 18/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0179 - val_loss: 0.0125
# Epoch 19/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0186 - val_loss: 0.0082
# Epoch 20/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0174 - val_loss: 0.0061
# Epoch 21/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0095
# Epoch 22/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.0079
# Epoch 23/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0146 - val_loss: 0.0072
# Epoch 24/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0135 - val_loss: 0.0074
# Epoch 25/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0133 - val_loss: 0.0069
# Epoch 26/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0131 - val_loss: 0.0058
# Epoch 27/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0130 - val_loss: 0.0070
# Epoch 28/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0133 - val_loss: 0.0051
# Epoch 29/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0130 - val_loss: 0.0080
# Epoch 30/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0074
# Epoch 31/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0077
# Epoch 32/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0028
# Epoch 33/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0065
# Epoch 34/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0121 - val_loss: 0.0077
# Epoch 35/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.0039
# Epoch 36/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 37/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0044
# Epoch 38/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0033
# Epoch 39/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 40/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0038
# Epoch 41/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0042
# Epoch 42/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.0028
# Epoch 43/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 44/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 45/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0039
# Epoch 46/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 47/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0037
# Epoch 48/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 49/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0031
# Epoch 50/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 51/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 52/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0036
# Epoch 53/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 54/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0039
# Epoch 55/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 56/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0033
# Epoch 57/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 58/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 59/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 60/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 61/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 62/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 63/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0035
# Epoch 64/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0041
# Epoch 65/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 66/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 67/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0043
# Epoch 68/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0039
# Epoch 69/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 70/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 71/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0039
# Epoch 72/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 73/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 74/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 75/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0036
# Epoch 76/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0041
# Epoch 77/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0036
# Epoch 78/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0038
# Epoch 79/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0042
# Epoch 80/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 81/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 82/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 83/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0043
# Epoch 84/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0030
# Epoch 85/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 86/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0033
# Epoch 87/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0046
# Epoch 88/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 89/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 90/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 91/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0038
# Epoch 92/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 93/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0034
# Epoch 94/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 95/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0037
# Epoch 96/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0061 - val_loss: 0.0035
# Epoch 97/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 98/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 99/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 100/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 101/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 102/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0036
# Epoch 103/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 104/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 105/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 106/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0043
# Epoch 107/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 108/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0032
# Epoch 109/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 110/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 111/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0035
# Epoch 112/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0045
# Epoch 113/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 114/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 115/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 116/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 117/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 118/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0033
# Epoch 119/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 120/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0039
# Epoch 121/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 122/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 123/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0036
# Epoch 124/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0035
# Epoch 125/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0042
# Epoch 126/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0033
# Epoch 127/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 128/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 129/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0037
# Epoch 130/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 131/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 132/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0040
# Epoch 133/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 134/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 135/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 136/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 137/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0032
# Epoch 138/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 139/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 140/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 141/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0038
# Epoch 142/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 143/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 144/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 145/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 146/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 147/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 148/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0037
# Epoch 149/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 150/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0040
# Epoch 151/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 152/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 153/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 154/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0062 - val_loss: 0.0047
# Epoch 155/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0031
# Epoch 156/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 157/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 158/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 159/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0042
# Epoch 160/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0033
# Epoch 161/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0038
# Epoch 162/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 163/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 164/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 165/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 166/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 167/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0042
# Epoch 168/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 169/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 170/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 171/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 172/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 173/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 174/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 175/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0036
# Epoch 176/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 177/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0042
# Epoch 178/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0040
# Epoch 179/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 180/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0037
# Epoch 181/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 182/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 183/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0032
# Epoch 184/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 185/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 186/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 187/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 188/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 189/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 190/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0042
# Epoch 191/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 192/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0039
# Epoch 193/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 194/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 195/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 196/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0029
# Epoch 197/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 198/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0041
# Epoch 199/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0033
# Epoch 200/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 201/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 202/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0038
# Epoch 203/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0041
# Epoch 204/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 205/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 206/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 207/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 208/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 209/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 210/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 211/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0033
# Epoch 212/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 213/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 214/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 215/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 216/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 217/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 218/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 219/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 220/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0046
# Epoch 221/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 222/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0037
# Epoch 223/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 224/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 225/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 226/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 227/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 228/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 229/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 230/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0032
# Epoch 231/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 232/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 233/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 234/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 235/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 236/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0042
# Epoch 237/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 238/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0033
# Epoch 239/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 240/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0037
# Epoch 241/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0038
# Epoch 242/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 243/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 244/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0031
# Epoch 245/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 246/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 247/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0029
# Epoch 248/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 249/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0031
# Epoch 250/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0043
# Epoch 251/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 252/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0047
# Epoch 253/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 254/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 255/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0054
# Epoch 256/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 257/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 258/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 259/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 260/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 261/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 262/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0032
# Epoch 263/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 264/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 265/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0032
# Epoch 266/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 267/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 268/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 269/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0041
# Epoch 270/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 271/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 272/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 273/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 274/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 275/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 276/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 277/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 278/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 279/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 280/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 281/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0042
# Epoch 282/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0031
# Epoch 283/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0043
# Epoch 284/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0057 - val_loss: 0.0032
# Epoch 285/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 286/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 287/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0032
# Epoch 288/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 289/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 290/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 291/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 292/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 293/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 294/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 295/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0058 - val_loss: 0.0029
# Epoch 296/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 297/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 298/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0032
# Epoch 299/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 300/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 301/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 302/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0055 - val_loss: 0.0052
# Epoch 303/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0031
# Epoch 304/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 305/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 306/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 307/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 308/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 309/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 310/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 311/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 312/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 313/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 314/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 315/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 316/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 317/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 318/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 319/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 320/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 321/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 322/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 323/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 324/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0041
# Epoch 325/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 326/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 327/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 328/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 329/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 330/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 331/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0034
# Epoch 332/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 333/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 334/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 335/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 336/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0039
# Epoch 337/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 338/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 339/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 340/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 341/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 342/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 343/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 344/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 345/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0037
# Epoch 346/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0033
# Epoch 347/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0033
# Epoch 348/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0044
# Epoch 349/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 350/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 351/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 352/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 353/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 354/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0034
# Epoch 355/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 356/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 357/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 358/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 359/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 360/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 361/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 362/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0031
# Epoch 363/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 364/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 365/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0033
# Epoch 366/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 367/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0031
# Epoch 368/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 369/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 370/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0030
# Epoch 371/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 372/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 373/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 374/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 375/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 376/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 377/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0034
# Epoch 378/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 379/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 380/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 381/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 382/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 383/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 384/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 385/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 386/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 387/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 388/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 389/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 390/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 391/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 392/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 393/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 394/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 395/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0038
# Epoch 396/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 397/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 398/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0036
# Epoch 399/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0038
# Epoch 400/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 401/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 402/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0036
# Epoch 403/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0034
# Epoch 404/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 405/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0042
# Epoch 406/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 407/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0038
# Epoch 408/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0031
# Epoch 409/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 410/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 411/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 412/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 413/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 414/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 415/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 0.0040
# Epoch 416/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 417/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0059 - val_loss: 0.0032
# Epoch 418/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 419/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 420/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 421/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 422/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 423/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0039
# Epoch 424/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 425/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 426/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 427/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 428/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 429/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 430/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 431/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 432/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 433/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 434/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 435/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 436/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 437/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 438/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 439/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 440/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 441/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 442/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 443/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 444/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 445/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0049
# Epoch 446/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 447/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 448/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 449/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 450/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 451/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 452/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 453/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0035
# Epoch 454/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 455/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 456/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 457/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 458/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 459/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0069 - val_loss: 0.0035
# Epoch 460/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 461/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 462/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 463/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 464/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0034
# Epoch 465/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 466/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 467/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0039
# Epoch 468/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 469/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0032
# Epoch 470/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 471/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 472/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 473/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 474/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 475/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 476/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0042 - val_loss: 0.0037
# Epoch 477/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 478/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 479/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 480/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 481/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 482/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0038
# Epoch 483/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 484/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 485/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 486/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 487/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 488/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0031
# Epoch 489/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0042
# Epoch 490/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 491/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 492/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 493/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 494/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 495/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 496/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 497/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0041
# Epoch 498/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0034
# Epoch 499/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 500/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0036

# %%
# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']

# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
plt.legend(['Training Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %% [markdown]
# ## Predictions on Test Data
#
# We now use the independent test data that we have retained earlier to validate the network.
# We start with the first sequence in the test data comprising of n consecutive data points and then predict the next point.
# Then we add this prediction to the sequence and move the prediction window one step ahead and predict the next point. We keep iterating this approach until we have processed the complete test data.

# %%
# start from the first window in the test data, i.e. sequence_length number of points
# with shape (sequence_length,1)
current_window = x_test[0]
prediction = []

for i in range(len(x_test)):
    #LSTM cell expects 3D shape, add a new axis
    data_point = current_window[np.newaxis,:,:]
    
    #get a single number from the returned shape as the prediction
    pred = model.predict(data_point)[0,0]
    prediction.append(pred)

    
    #advance the input window to the LSTM cell, move the sequence one step up, add the prediction as the last number
    current_window = current_window[1:]
    current_window = np.insert(current_window,[sequence_length -1 ], values=prediction[-1], axis=0)
# Out:
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# We now print the available data, starting with the training data. Then we overlay the known true values of the test data (in red) with the predictions
# from the LSTM network (in blue).
#
# On this scale the predictions are very accurate.

# %%
plt.plot(x[:train_index], y_train, label='Train', color='black',)
plt.plot(x[train_index:-sequence_length], y_test,  label='Test',  color='red', alpha=0.2)
plt.plot(x[train_index:-sequence_length], prediction,  label='Pred',  color='blue', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# Let's look at just the predictions and known true values.
# The model can accurately reproduce the shape of the signal without following the extra noise.

# %%
plt.plot(prediction, label='pred')
plt.plot(y_test, label='true')
plt.legend()
plt.show()
